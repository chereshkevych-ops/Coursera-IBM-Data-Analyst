# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Missing Values**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# Data wrangling is the process of cleaning, transforming, and organizing data to make it suitable for analysis. Finding and handling missing values is a crucial step in this process to ensure data accuracy and completeness. In this lab, you will focus exclusively on identifying and handling missing values in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Identify missing values in the dataset.
#
# - Quantify missing values for specific columns.
#
# - Impute missing values using various strategies.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# ##### Setup: Install Required Libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ##### Import Necessary Modules:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Tasks

# %% [markdown]
# <h2>1. Load the Dataset</h2>
# <p>
# We use the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
# Define the URL of the dataset
file_path ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/UDKAZw-kz18Yj8P6icf_qw/survey-data-duplicates.csv"

# Load the dataset into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### 2. Explore the Dataset
# ##### Task 1: Display basic information and summary statistics of the dataset.

# %%
## Write your code here
# Basic info (columns, types, null counts)
df.info()

# Summary statistics for numerical columns
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65447 entries, 0 to 65446
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 195.7 MB
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65447.000000   3.374000e+04  29659.000000    29325.000000
# mean   32714.001528  2.963841e+145     11.467143       18.580460
# std    18893.063225  5.444117e+147      9.168610       25.966005
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16352.500000   6.000000e+04      4.000000        0.000000
# 50%    32714.000000   1.100000e+05      9.000000       10.000000
# 75%    49075.500000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29394.000000    29412.000000    29451.000000    29449.000000
# ...

# %% [markdown]
# ### 3. Finding Missing Values
# ##### Task 2: Identify missing values for all columns.

# %%
## Write your code here
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10635
#                        ...
# JobSatPoints_11        36001
# SurveyLength            9257
# SurveyEase              9201
# ConvertedCompYearly    42012
# JobSat                 36321
# Length: 114, dtype: int64

# %% [markdown]
# ##### Task 3: Visualize missing values using a heatmap (Using seaborn library).

# %%
## Write your code here
import seaborn as sns
import matplotlib.pyplot as plt

# Create a dataframe of missing values
data = df.isnull().sum().reset_index()
data.columns = ['Column', 'Missing Values']

# Filter to only columns that have missing values
data = data[data['Missing Values'] > 0]

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(data.set_index('Column'), annot=False, fmt='d', cmap='Blues')
plt.title('Missing Values Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Task 4: Count the number of missing rows for a specific column (e.g., `Employment`).

# %%
## Write your code here
print(df['RemoteWork'].isnull().sum())
# Out:
# 10635

# %% [markdown]
# ### 4. Imputing Missing Values
# ##### Task 5: Identify the most frequent (majority) value in a specific column (e.g., `Employment`).

# %%
## Write your code here
most_frequent = df['RemoteWork'].value_counts()
print(most_frequent)
most_frequent = df['RemoteWork'].mode()[0]
print('The most frequent (majority) value of Remote Work is: ',most_frequent)
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    23015
# Remote                                  20836
# In-person                               10961
# Name: count, dtype: int64
# The most frequent (majority) value of Remote Work is:  Hybrid (some remote, some in-person)

# %% [markdown]
# ##### Task 6: Impute missing values in the `Employment` column with the most frequent value.

# %%
## Write your code here
df['Employmen_fill'] = df['Employment'].fillna(df['Employment'].mode()[0])

# %% [markdown]
# ### 5. Visualizing Imputed Data
# ##### Task 7: Visualize the distribution of a column after imputation (e.g., `Employment`).

# %%
## Write your code here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a copy to distinguish imputed points (simulated)
df['Imputed_Flag'] = df['Employment'].isna()
df['Employment_Imputed'] = df['Employment'].fillna(df['Employment'].mode()[0])

# Set up the plotting environment
plt.figure(figsize=(10, 6))
"""
# Plot the distribution of the imputed column
#sns.kdeplot(df['Employment_Imputed'].value_counts().head(10), fill=True, color='orange', label='Post-Imputation', alpha=0.6)
# Overlay the original data (with missing values dropped)
#sns.kdeplot(df['Employment'].value_counts().head(10), fill=True, color='blue', label='Pre-Imputation', alpha=0.4)

# Instead of kdeplot, try a count plot
sns.countplot(data=df, x='Employment_Imputed', alpha=0.8, color='orange', label='Post-Imputation')
sns.countplot(data=df, x='Employment', alpha=0.3, color='blue', label='Pre-Imputation')

# Format the visualization
plt.title('Distribution of Employment: Pre vs. Post Imputation', fontsize=14)
plt.xlabel('Employment Type')
plt.ylabel('Density', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tick_params(axis='x', labelsize=8)
plt.tight_layout()
plt.legend()
plt.show()
"""
#Bar diagram
plt.figure(figsize=(10, 6))
df['Employment_Imputed'].value_counts().head(10).plot(kind='bar')
plt.title('Distribution of Employment After Imputation')
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tick_params(axis='x', labelsize=8)
plt.tight_layout()
plt.show()

df.to_csv('survey_cleaned.csv', index=False)

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you:
# - Loaded the dataset into a pandas DataFrame.
# - Identified missing values across all columns.
# - Quantified missing values in specific columns.
# - Imputed missing values in a categorical column using the most frequent value.
# - Visualized the imputed data for better understanding.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
